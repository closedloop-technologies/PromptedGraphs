# %% [markdown]
# # QA pipline

# %%
from spacy import displacy
from promptedgraphs.config import Config
from promptedgraphs.entity_recognition import extract_entities

labels = {
    "person:name": "First and or last name of the person.",
    "person:date_of_birth": "Date of birth of the person.",
    "person:email": "Email address of the person. Must be unique.",
    "person:phone_number": "Phone number of the person.",
    "person:address": "Physical address of the person.",
    "person:profile_picture": "URL or path to the profile picture of the person.",
    "relationship:relationship_type": "Type of relationship (e.g., friend, family, colleague, spouse).",
    "person_relationship:start_date": "Start date of the relationship.",
    "person_relationship:end_date": "End date of the relationship, if applicable."
}

question = "Where was the husband of Michelle Obama born?"

# Label Sentiment
ents = []
async for msg in extract_entities(
    text=question,
    labels=labels,
    config=Config(),  # Reads `OPENAI_API_KEY` from .env file or environment
):
    ents.append(msg)

# Show Results using spacy.displacy
displacy.render(
    {
        "text": question,
        "ents": [e.to_dict() for e in ents],
    },
    style="ent",
    jupyter=True,
    manual=True,
)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Where was the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     husband
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">person_relationship:relationship_type</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michelle Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">person:name</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     born
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">==NONE==</span>
# </mark>
# ?</div></span>

# %%
# Out:
# ('person:name', 'Michelle Obama')

# %% [markdown]
# ## Notes on WikiData
#
# Property definitions are located here:
# https://www.wikidata.org/wiki/Wikidata:Database_reports/List_of_properties/all
#
# Here's one example of the API
# https://doc.wikimedia.org/Wikibase/master/js/rest-api/
# https://en.wikipedia.org/api/rest_v1/#/Page%20content/get_page_html__title_
# https://www.wikidata.org/wiki/Special:ApiSandbox#action=wbgetclaims&format=json&formatversion=2
#
#
# Property information for a given entity can have
#  * qualifiers (like references to times and places)
#  * references (references to why the statement is true)
#
#
# https://www.mediawiki.org/wiki/Wikibase/DataModel#Snaks

# %%
import requests
import json 
# https://www.wikidata.org/wiki/Special:ApiSandbox#action=wbsearchentities&format=json&search=alphabet&language=en&formatversion=2

q = f"{ents[1].text}"
url = f"https://www.wikidata.org/w/api.php?action=wbsearchentities&format=json&search={q}&language=en&formatversion=2"
rs = requests.get(url)

# %%
top_id = json.loads(rs.content.decode('utf-8'))['search'][0].get('id')
top_id
# Out:
# 'Q13133'

# %%
url = "https://www.wikidata.org/wiki/Q13133"
rs = requests.get(url)

# %%
# Get ID from the wbsearchentities response
import requests
 
def fetch_wikidata(params):
    url = 'https://www.wikidata.org/w/api.php'
    try:
        return requests.get(url, params=params)
    except:
        return 'There was and error'
# Create parameters
top_id = "Q76"
params = {
            'action': 'wbgetentities',
            'ids':top_id, 
            'format': 'json',
            'languages': 'en'
        }
 
# fetch the API
data = fetch_wikidata(params)
 
# Show response
data = data.json()
data
# Out:
# {'entities': {'Q76': {'pageid': 205,
#    'ns': 0,
#    'title': 'Q76',
#    'lastrevid': 1982189039,
#    'modified': '2023-09-26T20:50:39Z',
#    'type': 'item',
#    'id': 'Q76',
#    'labels': {'en': {'language': 'en', 'value': 'Barack Obama'}},
#    'descriptions': {'en': {'language': 'en',
#      'value': 'president of the United States from 2009 to 2017'}},
#    'aliases': {'en': [{'language': 'en', 'value': 'Barack Hussein Obama II'},
#      {'language': 'en', 'value': 'Barack Obama II'},
#      {'language': 'en', 'value': 'Barack Hussein Obama'},
#      {'language': 'en', 'value': 'Obama'},
#      {'language': 'en', 'value': 'Barak Obama'},
#      {'language': 'en', 'value': 'Barry Obama'},
#      {'language': 'en', 'value': 'President Obama'},
#      {'language': 'en', 'value': 'President Barack Obama'},
#      {'language': 'en', 'value': 'BHO'},
#      {'language': 'en', 'value': 'Barack'},
#      {'language': 'en', 'value': 'Barack H. Obama'},
#      {'language': 'en', 'value': 'Honorable Barack Obama'}]},
#    'claims': {'P31': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': 'ad7d38a03cdd40cdc373de0dc4e7b7fcbccb31d9',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 5,
#          'id': 'Q5'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q76$9c7254c8-4792-aa55-0af8-8c589c9bd68a',
#       'rank': 'normal',
#       'references': [{'hash': 'e01a1ff109c47466d8ad80c70d7a12130210731b',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'def9f19d84b65167a2a17ce38364d264c16127fc',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 19938912,
#              'id': 'Q19938912'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'd6162a1716489623c6e595e448b17f8dca4fb2e8',
#            'datavalue': {'value': {'time': '+2015-10-10T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '84938e87092fcb4899f162e2fc53539dc79df771',
#            'datavalue': {'value': 'http://data.bnf.fr/ark:/12148/cb15591663c',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1065': [{'snaktype': 'value',
#            'property': 'P1065',
#            'hash': 'f10f1ae344a79f215b383d788eec29782de28226',
#            'datavalue': {'value': 'https://web.archive.org/web/20201226103548/https://data.bnf.fr/en/15591663/barack_obama/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P2960': [{'snaktype': 'value',
#            'property': 'P2960',
#            'hash': '3bdd92b49c24fecaf373afc66973656a6318890b',
#            'datavalue': {'value': {'time': '+2020-12-26T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813', 'P854', 'P1065', 'P2960']}]}],
#     'P21': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P21',
#        'hash': '85ad4b1c7348f7a5aac521135040d74e91fb5939',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 6581097,
#          'id': 'Q6581097'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q76$545B2D30-AD63-4698-9224-DDB75CC685FC',
#       'rank': 'normal',
#       'references': [{'hash': 'e91a853ea4e0b372b26f82a616b87eb645b0aff3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']},
#        {'hash': '5e4048b7afad771ef0c09337bd307da62751e215',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'def9f19d84b65167a2a17ce38364d264c16127fc',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 19938912,
#              'id': 'Q19938912'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'd6162a1716489623c6e595e448b17f8dca4fb2e8',
#            'datavalue': {'value': {'time': '+2015-10-10T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '84938e87092fcb4899f162e2fc53539dc79df771',
#            'datavalue': {'value': 'http://data.bnf.fr/ark:/12148/cb15591663c',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P248', 'P813', 'P854']},
#        {'hash': '63309730314f4c20bf6b1008fe8ffd2b155272b3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '6b7d4330c4aac4caec4ede9de0311ce273f88ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 54919,
#              'id': 'Q54919'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']},
#        {'hash': '207f35a0ea83b330f87438c914b0ab24558d2868',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 36578,
#              'id': 'Q36578'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P227': [{'snaktype': 'value',
#            'property': 'P227',
#            'hash': '9f02abf3ea03d526890d76dc01ca547a29f8b131',
#            'datavalue': {'value': '132522136', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P407': [{'snaktype': 'value',
#            'property': 'P407',
#            'hash': '46bfd327b830f66f7061ea92d1be430c135fa91f',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 188,
#              'id': 'Q188'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e92d27129c65e9f77f424e786fcfc2c47e96d5fe',
#            'datavalue': {'value': {'time': '+2021-06-06T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P227', 'P407', 'P813']}]}],
#     'P27': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P27',
#        'hash': '52d0408c7915122e0519a22577f0cbdcb28f749b',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 30,
#          'id': 'Q30'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P1310': [{'snaktype': 'value',
#          'property': 'P1310',
#          'hash': 'a32d4811da28039799a992671e691fcb39d052d6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3137784,
#            'id': 'Q3137784'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P1310'],
#       'id': 'q76$FC5FD9FA-5950-4C70-BC52-E62E24A6A5F5',
#       'rank': 'normal',
#       'references': [{'hash': '432a0ca2fb174f03752efde33775db6373ea7cb2',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3865': [{'snaktype': 'value',
#            'property': 'P3865',
#            'hash': 'c4d2bd1d18df046328a7339b67bfc9d98fdbb048',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 83900,
#              'id': 'Q83900'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248', 'P3865']},
#        {'hash': '488d75a6c97b6c832e2d15ccf180c6ae802d63cd',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'f23ee8c5f0d2019c0973b46c2a5c2266585440ec',
#            'datavalue': {'value': 'http://www.nytimes.com/2009/12/15/business/economy/15obama.html',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']},
#        {'hash': '2f2f3302e41b9ef0d0b906e3e3d03ac650e853ae',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '8ccbe3013bda66a29567d727adb450e324088d56',
#            'datavalue': {'value': 'http://www.nytimes.com/2012/03/28/world/asia/president-obama-talks-missile-defense-at-nuclear-summit-in-south-korea.html?pagewanted=all',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']},
#        {'hash': '72897cac7193e59901513e79e80405cd812f2e10',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'cf65004e919ca3c2ec3243d582ec085d50559598',
#            'datavalue': {'value': 'http://www.nytimes.com/aponline/2014/11/19/us/politics/ap-us-obama-education.html',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P27',
#        'hash': '31c6ffadca3fba31fd6afb4a26820bc614ca67f0',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 114,
#          'id': 'Q114'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P582': [{'snaktype': 'value',
#          'property': 'P582',
#          'hash': '4b0031d9f9ee53325c2efc874893a7100a7354e1',
#          'datavalue': {'value': {'time': '+1982-08-04T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P582'],
#       'id': 'Q76$432352db-4cda-ae7b-93ba-8bf18f04988f',
#       'rank': 'normal',
#       'references': [{'hash': '79207df2239a16aec7bd961583c51be8fca9e63b',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'c5fe02118b51bbdd5e507f4cbb96e42bc02dcaac',
#            'datavalue': {'value': 'https://archive.nytimes.com/kristof.blogs.nytimes.com/2008/08/29/was-obama-a-kenyan-citizen/',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']},
#        {'hash': '78247f3102eed769611a4d3c9946e3d15c9e03c0',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'a11c255fa502bfbb6bf9945a5d7e937cab0474f4',
#            'datavalue': {'value': 'https://www.factcheck.org/2008/08/obamas-kenyan-citizenship/',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P569': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P569',
#        'hash': 'ed79f863229614970fb6a16ca9f9f1ab94e7f812',
#        'datavalue': {'value': {'time': '+1961-08-04T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 11,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'},
#       'type': 'statement',
#       'qualifiers': {'P4241': [{'snaktype': 'value',
#          'property': 'P4241',
#          'hash': '4ef3d38da5bb4352be4ef3422fe1fa61bb2d2d8a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 55812651,
#            'id': 'Q55812651'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P7452': [{'snaktype': 'value',
#          'property': 'P7452',
#          'hash': 'f9f842b41f249e5504d48025c7ad6d7b5bfc7496',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 71536040,
#            'id': 'Q71536040'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P4241', 'P7452'],
#       'id': 'q76$0ec26c64-4f00-e138-9516-2f9b50d240f7',
#       'rank': 'normal',
#       'references': [{'hash': '0f29314c43daf71253b5da9c5b4fb01b0bc0aa96',
#         'snaks': {'P244': [{'snaktype': 'value',
#            'property': 'P244',
#            'hash': '3320c40f2b1433a42bd64c0ec1367fdd644fb3c7',
#            'datavalue': {'value': 'n94112934', 'type': 'string'},
#            'datatype': 'external-id'}]},
#         'snaks-order': ['P244']},
#        {'hash': '432a0ca2fb174f03752efde33775db6373ea7cb2',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3865': [{'snaktype': 'value',
#            'property': 'P3865',
#            'hash': 'c4d2bd1d18df046328a7339b67bfc9d98fdbb048',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 83900,
#              'id': 'Q83900'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248', 'P3865']},
#        {'hash': 'abc9457dcf728dd069b8ed5b2e1a86035cf2b679',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 36578,
#              'id': 'Q36578'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '7805df7373a5e95763e019b855686d24acee918e',
#            'datavalue': {'value': {'time': '+2014-04-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P813']},
#        {'hash': '74de41be61a50e0c5615f743dc3101c031970a6b',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'fe1d24981b2395aa65acaa4cfa70580a1785c43c',
#            'datavalue': {'value': 'http://www.imdb.com/name/nm1682433/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '0068a6ea23b0337bd9b652f998d0030ac8ed7235',
#            'datavalue': {'value': {'time': '+2015-12-28T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': 'ffbfdc2c6246a6838831884b8edcd9dd140f1705',
#            'datavalue': {'value': {'text': 'Barack Obama', 'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P813', 'P1476']},
#        {'hash': '8bbbc3d212feb1a569b52bbb73ab778b2bbf3989',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'df18c3a835a35aff916e466431c1297887cd5ae0',
#            'datavalue': {'value': 'http://www.nobelprize.org/nobel_prizes/peace/laureates/2009/obama-facts.html',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '0068a6ea23b0337bd9b652f998d0030ac8ed7235',
#            'datavalue': {'value': {'time': '+2015-12-28T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': 'd7baedb8aa3749b6cbf0e2b85ccc523bf4e469b2',
#            'datavalue': {'value': {'text': 'Barack H. Obama Facts',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P813', 'P1476']},
#        {'hash': '8fc94c97f7647bcbf86d4167a3fccf2326a26e8d',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'dee3022ec24970657a992a2a969fffdc1236fbfb',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 17299517,
#              'id': 'Q17299517'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P650': [{'snaktype': 'value',
#            'property': 'P650',
#            'hash': '65ab8c0a9ace04d547bd6a5bf8efab72be2f57fe',
#            'datavalue': {'value': '424232', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#            'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P650', 'P1810', 'P813']},
#        {'hash': '1f867f82a9d8c03669210036c1a4ee5403790c32',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '2cb827dc711b8ec4594187170c0bce6d67f54fbe',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 21401824,
#              'id': 'Q21401824'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P4638': [{'snaktype': 'value',
#            'property': 'P4638',
#            'hash': '90774b82927c122ec8dd468c666be85c7673f7f7',
#            'datavalue': {'value': 'p69249.htm#i692484', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': 'b1b0873a897df066b1e3cf8da09094199076a42b',
#            'datavalue': {'value': 'Barack Obama, Jr.', 'type': 'string'},
#            'datatype': 'string'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#            'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P4638', 'P1810', 'P813']},
#        {'hash': 'f7310cff646323a5e2ce879468858878c8781aaa',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'c34208b35b041d6758e6b68814cd263cacdabb10',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 504063,
#              'id': 'Q504063'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P1953': [{'snaktype': 'value',
#            'property': 'P1953',
#            'hash': 'd75f1884e6d7f57ceeaec63ec75c92d6209555fc',
#            'datavalue': {'value': '1252891', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#            'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P1953', 'P1810', 'P813']},
#        {'hash': '7a47405db2c3c7afef7bc5b7022c827c82f3db04',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '155e1a7322c5a7febad55feba5ba4c3a2656b1c4',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 2877812,
#              'id': 'Q2877812'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3630': [{'snaktype': 'value',
#            'property': 'P3630',
#            'hash': '62cd0a1e6e64b60641522a0edcc241e411097ff5',
#            'datavalue': {'value': '46341', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#            'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P3630', 'P1810', 'P813']},
#        {'hash': '4a43888c54bb60f3700fec38bf72a34814c990ff',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'e2a81dbf2f7dd02b332d6358ef65f622f82e8cc3',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 237227,
#              'id': 'Q237227'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P5019': [{'snaktype': 'value',
#            'property': 'P5019',
#            'hash': 'f976f4e1907944486e6fdb56f5603bd841a3a7c9',
#            'datavalue': {'value': 'obama-barack-hussein', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '413f807368fdc49bce3d757df91338208b482857',
#            'datavalue': {'value': 'Barack Hussein Obama', 'type': 'string'},
#            'datatype': 'string'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e5f60ab0b03700bb883efce38f8022d023bc49fb',
#            'datavalue': {'value': {'time': '+2017-10-09T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P5019', 'P1810', 'P813']},
#        {'hash': 'fbff2d514da9c475919d05aeee2d26ccfe507a13',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '65bf94067e6255ff8d61c9c9535d98794a309a4c',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 746368,
#              'id': 'Q746368'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P4342': [{'snaktype': 'value',
#            'property': 'P4342',
#            'hash': '3d711ce991674c4fe04b5d5e2c294f55ab8b7700',
#            'datavalue': {'value': 'Barack_Obama', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}]},
#         'snaks-order': ['P248', 'P4342', 'P1810']},
#        {'hash': '66dc7ce7a67734762ec263055e83ac8b2b43ed4b',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '0a32608aa08f3426db7556421893b00049eafc86',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 98769076,
#              'id': 'Q98769076'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P8094': [{'snaktype': 'value',
#            'property': 'P8094',
#            'hash': '4f1a50de4b6c535ea7b1481c9aca015d5da7300e',
#            'datavalue': {'value': 'obamabarack', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}]},
#         'snaks-order': ['P248', 'P8094', 'P1810']},
#        {'hash': 'ad2b3c79078132802834d231690f69d53377ea33',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': 'de3c214ce935a04397d58aeb41705a360e984ff8',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 83365652,
#              'id': 'Q83365652'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P7929': [{'snaktype': 'value',
#            'property': 'P7929',
#            'hash': '352f080ef67b3de226b7b5c1f8367bd341b850c6',
#            'datavalue': {'value': 'p=barack;n=obama', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '3d481d2555a3746b0734e3b430dc3360978a484a',
#            'datavalue': {'value': 'Barack Obama', 'type': 'string'},
#            'datatype': 'string'}]},
#         'snaks-order': ['P248', 'P7929', 'P1810']}]}],
#     'P19': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P19',
#        'hash': '59efd29d956df410af5bd5bf4b373c3f36a88610',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 6366688,
#          'id': 'Q6366688'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P6375': [{'snaktype': 'value',
#          'property': 'P6375',
#          'hash': '2e9be82b6a3154de13d7196988eb8b40dc8f0252',
#          'datavalue': {'value': {'text': '6085 Kalanianaole Highway',
#            'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'}],
#        'P1932': [{'snaktype': 'value',
#          'property': 'P1932',
#          'hash': '6fd68e03eb688ae2bc3065f585acd78edbe8fa5b',
#          'datavalue': {'value': 'Kapiolani Maternity & Gynecological Hospital',
#           'type': 'string'},
#          'datatype': 'string'}],
#        'P7452': [{'snaktype': 'value',
#          'property': 'P7452',
#          'hash': 'f9f842b41f249e5504d48025c7ad6d7b5bfc7496',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 71536040,
#            'id': 'Q71536040'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P131': [{'snaktype': 'value',
#          'property': 'P131',
#          'hash': 'cb3f87742410967dc80b3283e954e888954144cf',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 782,
#            'id': 'Q782'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P17': [{'snaktype': 'value',
#          'property': 'P17',
#          'hash': 'be4c6eafa2984964f04be85667263f5642ba1a72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 30,
#            'id': 'Q30'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P6375', 'P1932', 'P7452', 'P131', 'P17'],
#       'id': 'Q76$6c5e3740-4ca4-de6a-1557-b623372dc93a',
#       'rank': 'preferred',
#       'references': [{'hash': 'e91a853ea4e0b372b26f82a616b87eb645b0aff3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P19',
#        'hash': '2077d58b480766760519b848da845eafe6d028a4',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 18094,
#          'id': 'Q18094'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P131': [{'snaktype': 'value',
#          'property': 'P131',
#          'hash': 'cb3f87742410967dc80b3283e954e888954144cf',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 782,
#            'id': 'Q782'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P17': [{'snaktype': 'value',
#          'property': 'P17',
#          'hash': 'be4c6eafa2984964f04be85667263f5642ba1a72',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 30,
#            'id': 'Q30'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P131', 'P17'],
#       'id': 'Q76$7ba7f268-4c19-b92f-7254-f8ed65aed53f',
#       'rank': 'normal',
#       'references': [{'hash': '207f35a0ea83b330f87438c914b0ab24558d2868',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '019a50b7de741e0068bde41c9d9955b22a5de47b',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 36578,
#              'id': 'Q36578'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P227': [{'snaktype': 'value',
#            'property': 'P227',
#            'hash': '9f02abf3ea03d526890d76dc01ca547a29f8b131',
#            'datavalue': {'value': '132522136', 'type': 'string'},
#            'datatype': 'external-id'}],
#          'P407': [{'snaktype': 'value',
#            'property': 'P407',
#            'hash': '46bfd327b830f66f7061ea92d1be430c135fa91f',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 188,
#              'id': 'Q188'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'e92d27129c65e9f77f424e786fcfc2c47e96d5fe',
#            'datavalue': {'value': {'time': '+2021-06-06T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P248', 'P227', 'P407', 'P813']}]}],
#     'P735': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P735',
#        'hash': '7ea8817828f7521b2b2bf98bb70658643c0ebed6',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 18643532,
#          'id': 'Q18643532'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P1545': [{'snaktype': 'value',
#          'property': 'P1545',
#          'hash': '2a1ced1dca90648ea7e306acbadd74fc81a10722',
#          'datavalue': {'value': '1', 'type': 'string'},
#          'datatype': 'string'}]},
#       'qualifiers-order': ['P1545'],
#       'id': 'Q76$27efb092-4707-f92f-9329-6703062b6004',
#       'rank': 'preferred',
#       'references': [{'hash': 'dcc530ceafb0cfa13a72982e758738aa89d4b415',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '8232e2c7d4725429d63c896b2d3bbfddccf0370f',
#            'datavalue': {'value': 'http://d-nb.info/gnd/132522136',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': 'd023ae6e3706045c8727a4cac10fb2dac860c788',
#            'datavalue': {'value': {'time': '+2015-06-02T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P1065': [{'snaktype': 'value',
#            'property': 'P1065',
#            'hash': 'f708cb5fbd3fe0c4d410f537547fd988e3ed8f9f',
#            'datavalue': {'value': 'https://web.archive.org/web/20090629063316/http://d-nb.info/gnd/132522136',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P2960': [{'snaktype': 'value',
#            'property': 'P2960',
#            'hash': '8aaaa03ff344e77fea315f98d5c19a8ba72ce460',
#            'datavalue': {'value': {'time': '+2009-06-29T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P854', 'P813', 'P1065', 'P2960']},
#        {'hash': '432a0ca2fb174f03752efde33775db6373ea7cb2',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3865': [{'snaktype': 'value',
#            'property': 'P3865',
#            'hash': 'c4d2bd1d18df046328a7339b67bfc9d98fdbb048',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 83900,
#              'id': 'Q83900'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248', 'P3865']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P735',
#        'hash': 'bb5392186ddfb03233e3185c88483245edd059ee',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 27101961,
#          'id': 'Q27101961'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P1545': [{'snaktype': 'value',
#          'property': 'P1545',
#          'hash': '7241753c62a310cf84895620ea82250dcea65835',
#          'datavalue': {'value': '2', 'type': 'string'},
#          'datatype': 'string'}]},
#       'qualifiers-order': ['P1545'],
#       'id': 'Q76$d1b9d93d-4759-6468-0431-4990d0bb085d',
#       'rank': 'normal',
#       'references': [{'hash': '432a0ca2fb174f03752efde33775db6373ea7cb2',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3865': [{'snaktype': 'value',
#            'property': 'P3865',
#            'hash': 'c4d2bd1d18df046328a7339b67bfc9d98fdbb048',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 83900,
#              'id': 'Q83900'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248', 'P3865']}]}],
#     'P25': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P25',
#        'hash': 'be3c39d29224c8d055d08830ebeef5c6f93a65fa',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 766106,
#          'id': 'Q766106'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q76$FA9FB959-71AF-4CD1-A53D-7D8228059BE4',
#       'rank': 'normal',
#       'references': [{'hash': 'e91a853ea4e0b372b26f82a616b87eb645b0aff3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P22': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P22',
#        'hash': '124bab458194455bd832bd5351b0175e1bab1839',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 649593,
#          'id': 'Q649593'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q76$2BBD9841-09A6-4862-9217-3C9BDB4E4684',
#       'rank': 'normal',
#       'references': [{'hash': 'e91a853ea4e0b372b26f82a616b87eb645b0aff3',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '4608e934acd2b7c9ef27de1caeeb0a9bbb68078d',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 14527788,
#              'id': 'Q14527788'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P26': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P26',
#        'hash': 'f825c6521e7f5d92299c39ee36d3b82dab622a97',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 13133,
#          'id': 'Q13133'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'qualifiers': {'P580': [{'snaktype': 'value',
#          'property': 'P580',
#          'hash': '36e31a1f1fc64c0f17750153a36cba27351a1065',
#          'datavalue': {'value': {'time': '+1992-10-03T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P2842': [{'snaktype': 'value',
#          'property': 'P2842',
#          'hash': '7794f0ca5420ffdea20c6359a608482dc6e0f27d',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 10703919,
#            'id': 'Q10703919'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P580', 'P2842'],
#       'id': 'q76$448BD1B3-5F06-4391-90A2-6C42408E645C',
#       'rank': 'normal',
#       'references': [{'hash': '8de409e9374ac1e110231b58003c9d2ca69ebd12',
#         'snaks': {'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': 'e6f61512a2e44ebfc77857b8f4f6f001cfe00c8a',
#            'datavalue': {'value': {'text': 'The Obamas’ Marriage',
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}],
#          'P50': [{'snaktype': 'value',
#            'property': 'P50',
#            'hash': '8b24b9e39b9b60ec4ef9039e1f1df16f6d10becd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 13605899,
#              'id': 'Q13605899'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P123': [{'snaktype': 'value',
#            'property': 'P123',
#            'hash': '2714993a93f86610bb90b55161a935eab4be05fc',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 9684,
#              'id': 'Q9684'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': '1e462507b5fed662ac79050aedc0c11064cff0f1',
#            'datavalue': {'value': {'time': '+2009-10-26T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P407': [{'snaktype': 'value',
#            'property': 'P407',
#            'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 1860,
#              'id': 'Q1860'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': '02ae4de28a72313c588cb956f457b4c34467c93f',
#            'datavalue': {'value': 'http://www.nytimes.com/2009/11/01/magazine/01Obama-t.html?pagewanted=all',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P813': [{'snaktype': 'value',
#            'property': 'P813',
#            'hash': '97f6f6c5ecc72204c398341b2079f643dd0fda27',
#            'datavalue': {'value': {'time': '+2014-11-25T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}],
#          'P1065': [{'snaktype': 'value',
#            'property': 'P1065',
#            'hash': '0f39339e5ccdeb882a99c92e2731ad88ba96e189',
#            'datavalue': {'value': 'https://web.archive.org/web/20141103015202/http://www.nytimes.com/2009/11/01/magazine/01Obama-t.html?pagewanted=all',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P2960': [{'snaktype': 'value',
#            'property': 'P2960',
#            'hash': '8784f09e69c230a7fd97ab54bc39d2a2125becc4',
#            'datavalue': {'value': {'time': '+2014-11-03T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 11,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'snaks-order': ['P1476',
#          'P50',
#          'P123',
#          'P577',
#          'P407',
#          'P854',
#          'P813',
#          'P1065',
#          'P2960']},
#        {'hash': '11dfa5bd4bfb803743f3f75ece888f3a06fb084b',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'e0a1c59f52a603b737eefadeff987a7a2430105b',
#            'datavalue': {'value': 'http://senatorobama.wordpress.com/barack-obamas-family/barack-obamas-marriage-license/',
#             'type': 'string'},
#            'datatype': 'url'}],
#          'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': '770508557f91e42952cc96036d40c03dc97bc849',
#            'datavalue': {'value': {'text': "Barack Obama's Marriage License : President Barack Obama - Fact And Fiction",
#              'language': 'en'},
#             'type': 'monolingualtext'},
#            'datatype': 'monolingualtext'}]},
#         'snaks-order': ['P854', 'P1476']}]}],
#     'P40': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P40',
#        'hash': 'f057a1c8a5850fc242d8d9c073e33f3ca0707a13',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 15070048,
#          'id': 'Q15070048'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q76$ea0c0eb0-4dda-915f-e46b-903c8d825479',
#       'rank': 'normal',
#       'references': [{'hash': '730311e5d42e569ffcc5f12a372b66910c33f384',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'b80d9730bf65864e1f871009e5e435132a6b237c',
#            'datavalue': {'value': 'https://www.gala.fr/stars_et_gotha/barack_obama',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']},
#        {'hash': '7f94a54dc73fbe176dabd7b4c4278fd43763bd28',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'df4b7bf081de48a06cc5f4b082d1e237a7a1ce3e',
#            'datavalue': {'value': 'https://www.voici.fr/bios-people/barack-obama',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P40',
#        'hash': '2343e0150e962e68bee06d2747b8403b1adac49f',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 15070044,
#          'id': 'Q15070044'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q76$a0f4b7fa-4f45-dc65-fdbb-60ca601045fb',
#       'rank': 'normal',
#       'references': [{'hash': '730311e5d42e569ffcc5f12a372b66910c33f384',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'b80d9730bf65864e1f871009e5e435132a6b237c',
#            'datavalue': {'value': 'https://www.gala.fr/stars_et_gotha/barack_obama',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']},
#        {'hash': '7f94a54dc73fbe176dabd7b4c4278fd43763bd28',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'df4b7bf081de48a06cc5f4b082d1e237a7a1ce3e',
#            'datavalue': {'value': 'https://www.voici.fr/bios-people/barack-obama',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P1050': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1050',
#        'hash': '8972d8fef888fc079d6e6a1645bcae43cb1e0754',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 223591,
#          'id': 'Q223591'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q76$f90d60fa-47a4-a84f-edb4-c70163472fdb',
#       'rank': 'normal',
#       'references': [{'hash': 'eaa17ba460fb19f2480577da41c3fe774576a6c1',
#         'snaks': {'P1476': [{'snaktype': 'value',
#            'property': 'P1476',
#            'hash': '86b3aeca67e20d6ac8bbc45ab24a544007f7a86e',
# ...
#     'hawiki': {'site': 'hawiki', 'title': 'Barack Obama', 'badges': []},
#     'hawwiki': {'site': 'hawwiki', 'title': 'Barack Obama', 'badges': []},
#     'hewiki': {'site': 'hewiki', 'title': 'ברק אובמה', 'badges': []},
#     'hewikiquote': {'site': 'hewikiquote', 'title': 'ברק אובמה', 'badges': []},
#     'hewikisource': {'site': 'hewikisource',
#      'title': 'מחבר:ברק אובמה',
#      'badges': []},
#     'hifwiki': {'site': 'hifwiki', 'title': 'Barack Obama', 'badges': []},
#     'hiwiki': {'site': 'hiwiki', 'title': 'बराक ओबामा', 'badges': []},
#     'hrwiki': {'site': 'hrwiki', 'title': 'Barack Obama', 'badges': []},
#     'hsbwiki': {'site': 'hsbwiki', 'title': 'Barack Obama', 'badges': []},
#     'htwiki': {'site': 'htwiki', 'title': 'Barack Obama', 'badges': []},
#     'huwiki': {'site': 'huwiki', 'title': 'Barack Obama', 'badges': []},
#     'huwikinews': {'site': 'huwikinews',
#      'title': 'Kategória:Barack Obama',
#      'badges': []},
#     'huwikiquote': {'site': 'huwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'hywiki': {'site': 'hywiki', 'title': 'Բարաք Օբամա', 'badges': []},
#     'hywwiki': {'site': 'hywwiki', 'title': 'Պարաք Օպամա', 'badges': []},
#     'iawiki': {'site': 'iawiki', 'title': 'Barack Obama', 'badges': []},
#     'idwiki': {'site': 'idwiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437798']},
#     'idwikiquote': {'site': 'idwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'iewiki': {'site': 'iewiki', 'title': 'Barack Obama', 'badges': []},
#     'igwiki': {'site': 'igwiki', 'title': 'Barack Obama', 'badges': []},
#     'ilowiki': {'site': 'ilowiki', 'title': 'Barack Obama', 'badges': []},
#     'iowiki': {'site': 'iowiki', 'title': 'Barack Obama', 'badges': []},
#     'iswiki': {'site': 'iswiki', 'title': 'Barack Obama', 'badges': []},
#     'itwiki': {'site': 'itwiki', 'title': 'Barack Obama', 'badges': []},
#     'itwikinews': {'site': 'itwikinews',
#      'title': 'Categoria:Barack Obama',
#      'badges': []},
#     'itwikiquote': {'site': 'itwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'iuwiki': {'site': 'iuwiki', 'title': 'ᐸᕌᒃ ᐅᐹᒪ', 'badges': []},
#     'jawiki': {'site': 'jawiki', 'title': 'バラク・オバマ', 'badges': []},
#     'jawikisource': {'site': 'jawikisource',
#      'title': '作者:バラク・オバマ',
#      'badges': []},
#     'jbowiki': {'site': 'jbowiki', 'title': 'byRAK.obamas', 'badges': []},
#     'jvwiki': {'site': 'jvwiki', 'title': 'Barack Obama', 'badges': []},
#     'kaawiki': {'site': 'kaawiki', 'title': 'Barak Obama', 'badges': []},
#     'kabwiki': {'site': 'kabwiki', 'title': 'Barack Obama', 'badges': []},
#     'kawiki': {'site': 'kawiki', 'title': 'ბარაკ ობამა', 'badges': []},
#     'kawikiquote': {'site': 'kawikiquote',
#      'title': 'ბარაკ ობამა',
#      'badges': []},
#     'kbpwiki': {'site': 'kbpwiki', 'title': 'Barack Obama', 'badges': []},
#     'kiwiki': {'site': 'kiwiki', 'title': 'Barrack Obama', 'badges': []},
#     'kkwiki': {'site': 'kkwiki', 'title': 'Барак Обама', 'badges': []},
#     'klwiki': {'site': 'klwiki', 'title': 'Barack Obama', 'badges': []},
#     'kmwiki': {'site': 'kmwiki', 'title': 'បារ៉ាក់ អូបាម៉ា', 'badges': []},
#     'knwiki': {'site': 'knwiki', 'title': 'ಬರಾಕ್ ಒಬಾಮ', 'badges': []},
#     'knwikiquote': {'site': 'knwikiquote',
#      'title': 'ಬರಾಕ್ ಒಬಾಮ',
#      'badges': []},
#     'kowiki': {'site': 'kowiki', 'title': '버락 오바마', 'badges': []},
#     'kowikinews': {'site': 'kowikinews', 'title': '분류:버락 오바마', 'badges': []},
#     'kowikiquote': {'site': 'kowikiquote', 'title': '버락 오바마', 'badges': []},
#     'kowikisource': {'site': 'kowikisource',
#      'title': '저자:버락 오바마',
#      'badges': []},
#     'kshwiki': {'site': 'kshwiki', 'title': 'Barack Obama', 'badges': []},
#     'kswiki': {'site': 'kswiki', 'title': 'بَراک اؤبامہ', 'badges': []},
#     'kuwiki': {'site': 'kuwiki', 'title': 'Barack Obama', 'badges': []},
#     'kwwiki': {'site': 'kwwiki', 'title': 'Barack Obama', 'badges': []},
#     'kywiki': {'site': 'kywiki', 'title': 'Барак Обама', 'badges': []},
#     'ladwiki': {'site': 'ladwiki', 'title': 'Barack Obama', 'badges': []},
#     'lawiki': {'site': 'lawiki', 'title': 'Baracus Obama', 'badges': []},
#     'lbwiki': {'site': 'lbwiki', 'title': 'Barack Obama', 'badges': []},
#     'lfnwiki': {'site': 'lfnwiki', 'title': 'Barack Obama', 'badges': []},
#     'lijwiki': {'site': 'lijwiki', 'title': 'Barack Obama', 'badges': []},
#     'liwiki': {'site': 'liwiki', 'title': 'Barack Obama', 'badges': []},
#     'liwikiquote': {'site': 'liwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'lmowiki': {'site': 'lmowiki', 'title': 'Barack Obama', 'badges': []},
#     'lnwiki': {'site': 'lnwiki', 'title': 'Barack Obama', 'badges': []},
#     'lowiki': {'site': 'lowiki', 'title': 'ບາຣັກ ໂອບາມາ', 'badges': []},
#     'ltgwiki': {'site': 'ltgwiki', 'title': 'Baraks Obama', 'badges': []},
#     'ltwiki': {'site': 'ltwiki', 'title': 'Barack Obama', 'badges': []},
#     'lvwiki': {'site': 'lvwiki', 'title': 'Baraks Obama', 'badges': []},
#     'maiwiki': {'site': 'maiwiki', 'title': 'बाराक ओबामा', 'badges': []},
#     'map_bmswiki': {'site': 'map_bmswiki',
#      'title': 'Barack Obama',
#      'badges': []},
#     'mgwiki': {'site': 'mgwiki', 'title': 'Barack Obama', 'badges': []},
#     'mhrwiki': {'site': 'mhrwiki', 'title': 'Обама, Барак', 'badges': []},
#     'miwiki': {'site': 'miwiki', 'title': 'Barack Obama', 'badges': []},
#     'mkwiki': {'site': 'mkwiki', 'title': 'Барак Обама', 'badges': []},
#     'mlwiki': {'site': 'mlwiki', 'title': 'ബറാക്ക് ഒബാമ', 'badges': []},
#     'mnwiki': {'site': 'mnwiki', 'title': 'Барак Обама', 'badges': []},
#     'mrwiki': {'site': 'mrwiki',
#      'title': 'बराक ओबामा',
#      'badges': ['Q17437796']},
#     'mswiki': {'site': 'mswiki', 'title': 'Barack Obama', 'badges': []},
#     'mtwiki': {'site': 'mtwiki', 'title': 'Barack Obama', 'badges': []},
#     'myvwiki': {'site': 'myvwiki', 'title': 'Обамань Барак', 'badges': []},
#     'mywiki': {'site': 'mywiki', 'title': 'ဘာရက် အိုဘားမား', 'badges': []},
#     'mznwiki': {'site': 'mznwiki', 'title': 'باراک اوباما', 'badges': []},
#     'nahwiki': {'site': 'nahwiki', 'title': 'Barack Obama', 'badges': []},
#     'napwiki': {'site': 'napwiki', 'title': 'Barack Obama', 'badges': []},
#     'nds_nlwiki': {'site': 'nds_nlwiki',
#      'title': 'Barack Obama',
#      'badges': []},
#     'ndswiki': {'site': 'ndswiki', 'title': 'Barack Obama', 'badges': []},
#     'newiki': {'site': 'newiki', 'title': 'बाराक ओबामा', 'badges': []},
#     'newwiki': {'site': 'newwiki', 'title': 'बाराक ओबामा', 'badges': []},
#     'niawiki': {'site': 'niawiki', 'title': 'Barack Obama', 'badges': []},
#     'nlwiki': {'site': 'nlwiki', 'title': 'Barack Obama', 'badges': []},
#     'nlwikinews': {'site': 'nlwikinews',
#      'title': 'Categorie:Barack Obama',
#      'badges': []},
#     'nlwikiquote': {'site': 'nlwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'nnwiki': {'site': 'nnwiki', 'title': 'Barack Obama', 'badges': []},
#     'nowiki': {'site': 'nowiki', 'title': 'Barack Obama', 'badges': []},
#     'nowikinews': {'site': 'nowikinews',
#      'title': 'Kategori:Barack Obama',
#      'badges': []},
#     'nowikiquote': {'site': 'nowikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'nqowiki': {'site': 'nqowiki', 'title': 'ߓߙߊߞ ߏߓߡߊ߫', 'badges': []},
#     'nrmwiki': {'site': 'nrmwiki', 'title': 'Barack Obama', 'badges': []},
#     'nsowiki': {'site': 'nsowiki', 'title': 'Barack Obama', 'badges': []},
#     'nvwiki': {'site': 'nvwiki',
#      'title': 'Hastiin alą́ąjįʼ dahsidáhígíí Barack Obama',
#      'badges': []},
#     'nywiki': {'site': 'nywiki', 'title': 'Barack Obama', 'badges': []},
#     'ocwiki': {'site': 'ocwiki', 'title': 'Barack Obama', 'badges': []},
#     'orwiki': {'site': 'orwiki', 'title': 'ବାରାକ ଓବାମା', 'badges': []},
#     'oswiki': {'site': 'oswiki', 'title': 'Обама, Барак', 'badges': []},
#     'pagwiki': {'site': 'pagwiki', 'title': 'Barack Obama', 'badges': []},
#     'pamwiki': {'site': 'pamwiki', 'title': 'Barack Obama', 'badges': []},
#     'papwiki': {'site': 'papwiki', 'title': 'Barack Obama', 'badges': []},
#     'pawiki': {'site': 'pawiki', 'title': 'ਬਰਾਕ ਓਬਾਮਾ', 'badges': []},
#     'pdcwiki': {'site': 'pdcwiki', 'title': 'Barack Obama', 'badges': []},
#     'pihwiki': {'site': 'pihwiki', 'title': 'Barak Obama', 'badges': []},
#     'plwiki': {'site': 'plwiki', 'title': 'Barack Obama', 'badges': []},
#     'plwikiquote': {'site': 'plwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'plwikisource': {'site': 'plwikisource',
#      'title': 'Autor:Barack Obama',
#      'badges': []},
#     'pmswiki': {'site': 'pmswiki', 'title': 'Barack Obama', 'badges': []},
#     'pnbwiki': {'site': 'pnbwiki', 'title': 'بارک اوباما', 'badges': []},
#     'pswiki': {'site': 'pswiki', 'title': 'باراک حسين اوباما', 'badges': []},
#     'ptwiki': {'site': 'ptwiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437796']},
#     'ptwikinews': {'site': 'ptwikinews',
#      'title': 'Categoria:Barack Obama',
#      'badges': []},
#     'ptwikiquote': {'site': 'ptwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'quwiki': {'site': 'quwiki', 'title': 'Barack Obama', 'badges': []},
#     'rmwiki': {'site': 'rmwiki', 'title': 'Barack Obama', 'badges': []},
#     'rmywiki': {'site': 'rmywiki', 'title': 'Barack Obama', 'badges': []},
#     'roa_tarawiki': {'site': 'roa_tarawiki',
#      'title': 'Barack Obama',
#      'badges': []},
#     'rowiki': {'site': 'rowiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437796']},
#     'ruewiki': {'site': 'ruewiki', 'title': 'Барак Обама', 'badges': []},
#     'ruwiki': {'site': 'ruwiki', 'title': 'Обама, Барак', 'badges': []},
#     'ruwikinews': {'site': 'ruwikinews',
#      'title': 'Категория:Барак Обама',
#      'badges': []},
#     'ruwikiquote': {'site': 'ruwikiquote',
#      'title': 'Барак Обама',
#      'badges': []},
#     'rwwiki': {'site': 'rwwiki', 'title': 'Barack Obama', 'badges': []},
#     'sahwiki': {'site': 'sahwiki', 'title': 'Барак Обама', 'badges': []},
#     'satwiki': {'site': 'satwiki', 'title': 'ᱵᱟᱨᱟᱠ ᱚᱵᱟᱢᱟ', 'badges': []},
#     'sawiki': {'site': 'sawiki', 'title': 'बराक् ओबामा', 'badges': []},
#     'scnwiki': {'site': 'scnwiki', 'title': 'Barack Obama', 'badges': []},
#     'scowiki': {'site': 'scowiki', 'title': 'Barack Obama', 'badges': []},
#     'scwiki': {'site': 'scwiki', 'title': 'Barack Obama', 'badges': []},
#     'sdwiki': {'site': 'sdwiki', 'title': 'بارڪ اوباما', 'badges': []},
#     'sewiki': {'site': 'sewiki', 'title': 'Barack Obama', 'badges': []},
#     'shiwiki': {'site': 'shiwiki', 'title': 'Barak Ubama', 'badges': []},
#     'shwiki': {'site': 'shwiki', 'title': 'Barack Obama', 'badges': []},
#     'simplewiki': {'site': 'simplewiki',
#      'title': 'Barack Obama',
#      'badges': []},
#     'simplewikiquote': {'site': 'simplewikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'siwiki': {'site': 'siwiki', 'title': 'බරාක් ඔබාමා', 'badges': []},
#     'skwiki': {'site': 'skwiki', 'title': 'Barack Obama', 'badges': []},
#     'slwiki': {'site': 'slwiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437796']},
#     'smnwiki': {'site': 'smnwiki', 'title': 'Barack Obama', 'badges': []},
#     'sowiki': {'site': 'sowiki', 'title': 'Baraak Obama', 'badges': []},
#     'sqwiki': {'site': 'sqwiki', 'title': 'Barack Obama', 'badges': []},
#     'srnwiki': {'site': 'srnwiki', 'title': 'Barack Obama', 'badges': []},
#     'srwiki': {'site': 'srwiki', 'title': 'Барак Обама', 'badges': []},
#     'srwikinews': {'site': 'srwikinews',
#      'title': 'Категорија:Барак Обама',
#      'badges': []},
#     'srwikiquote': {'site': 'srwikiquote',
#      'title': 'Барак Обама',
#      'badges': []},
#     'sswiki': {'site': 'sswiki', 'title': 'Barack Obama', 'badges': []},
#     'stqwiki': {'site': 'stqwiki', 'title': 'Barack Obama', 'badges': []},
#     'suwiki': {'site': 'suwiki', 'title': 'Barack Obama', 'badges': []},
#     'svwiki': {'site': 'svwiki', 'title': 'Barack Obama', 'badges': []},
#     'svwikinews': {'site': 'svwikinews',
#      'title': 'Kategori:Barack Obama',
#      'badges': []},
#     'svwikiquote': {'site': 'svwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'svwikisource': {'site': 'svwikisource',
#      'title': 'Författare:Barack Obama',
#      'badges': []},
#     'swwiki': {'site': 'swwiki', 'title': 'Barack Obama', 'badges': []},
#     'szlwiki': {'site': 'szlwiki', 'title': 'Barack Obama', 'badges': []},
#     'tawiki': {'site': 'tawiki', 'title': 'பராக் ஒபாமா', 'badges': []},
#     'tawikiquote': {'site': 'tawikiquote',
#      'title': 'பராக் ஒபாமா',
#      'badges': []},
#     'tetwiki': {'site': 'tetwiki', 'title': 'Barack Obama', 'badges': []},
#     'tewiki': {'site': 'tewiki', 'title': 'బరాక్ ఒబామా', 'badges': []},
#     'tgwiki': {'site': 'tgwiki', 'title': 'Барак Обама', 'badges': []},
#     'thwiki': {'site': 'thwiki',
#      'title': 'บารัก โอบามา',
#      'badges': ['Q17437796']},
#     'thwikiquote': {'site': 'thwikiquote',
#      'title': 'บารัก โอบามา',
#      'badges': []},
#     'tkwiki': {'site': 'tkwiki', 'title': 'Barak Obama', 'badges': []},
#     'tlwiki': {'site': 'tlwiki', 'title': 'Barack Obama', 'badges': []},
#     'tpiwiki': {'site': 'tpiwiki', 'title': 'Barack Obama', 'badges': []},
#     'trwiki': {'site': 'trwiki', 'title': 'Barack Obama', 'badges': []},
#     'trwikinews': {'site': 'trwikinews',
#      'title': 'Kategori:Barack Obama',
#      'badges': []},
#     'trwikiquote': {'site': 'trwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'trwikisource': {'site': 'trwikisource',
#      'title': 'Kişi:Barack Obama',
#      'badges': []},
#     'ttwiki': {'site': 'ttwiki', 'title': 'Барак Обама', 'badges': []},
#     'tywiki': {'site': 'tywiki', 'title': 'Barack Obama', 'badges': []},
#     'ugwiki': {'site': 'ugwiki', 'title': 'باراك ئوباما', 'badges': []},
#     'ukwiki': {'site': 'ukwiki', 'title': 'Барак Обама', 'badges': []},
#     'ukwikinews': {'site': 'ukwikinews',
#      'title': 'Категорія:Барак Обама',
#      'badges': []},
#     'ukwikiquote': {'site': 'ukwikiquote',
#      'title': 'Барак Обама',
#      'badges': []},
#     'urwiki': {'site': 'urwiki', 'title': 'بارک اوباما', 'badges': []},
#     'uzwiki': {'site': 'uzwiki', 'title': 'Barack Obama', 'badges': []},
#     'uzwikiquote': {'site': 'uzwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'vecwiki': {'site': 'vecwiki', 'title': 'Barack Obama', 'badges': []},
#     'vepwiki': {'site': 'vepwiki', 'title': 'Obama Barak', 'badges': []},
#     'viwiki': {'site': 'viwiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437798']},
#     'viwikiquote': {'site': 'viwikiquote',
#      'title': 'Barack Obama',
#      'badges': []},
#     'viwikisource': {'site': 'viwikisource',
#      'title': 'Tác gia:Barack Hussein Obama',
#      'badges': []},
#     'vlswiki': {'site': 'vlswiki', 'title': 'Barack Obama', 'badges': []},
#     'vowiki': {'site': 'vowiki', 'title': 'Barack Obama', 'badges': []},
#     'warwiki': {'site': 'warwiki', 'title': 'Barack Obama', 'badges': []},
#     'wawiki': {'site': 'wawiki', 'title': 'Barack Obama', 'badges': []},
#     'wuuwiki': {'site': 'wuuwiki', 'title': '巴拉克·奥巴马', 'badges': []},
#     'xmfwiki': {'site': 'xmfwiki', 'title': 'ბარაკ ობამა', 'badges': []},
#     'yiwiki': {'site': 'yiwiki', 'title': 'באראק אבאמא', 'badges': []},
#     'yowiki': {'site': 'yowiki',
#      'title': 'Barack Obama',
#      'badges': ['Q17437798']},
#     'zawiki': {'site': 'zawiki', 'title': 'Aubahmaj', 'badges': []},
#     'zeawiki': {'site': 'zeawiki', 'title': 'Barack Obama', 'badges': []},
#     'zh_min_nanwiki': {'site': 'zh_min_nanwiki',
#      'title': 'Barack Obama',
#      'badges': []},
#     'zh_yuewiki': {'site': 'zh_yuewiki', 'title': '巴拉克·奧巴馬', 'badges': []},
#     'zhwiki': {'site': 'zhwiki', 'title': '贝拉克·奥巴马', 'badges': []},
#     'zhwikinews': {'site': 'zhwikinews',
#      'title': 'Category:巴拉克·奥巴马',
#      'badges': []},
#     'zhwikiquote': {'site': 'zhwikiquote', 'title': '巴拉克·奥巴马', 'badges': []},
#     'zhwikisource': {'site': 'zhwikisource',
#      'title': 'Author:巴拉克·奥巴马',
#      'badges': []},
#     'zuwiki': {'site': 'zuwiki', 'title': 'Barack Obama', 'badges': []}}}},
#  'success': 1}

# %%
for c,v in data['entities'][top_id]['claims'].items():
    if c == 'P26':
        break

c,v
# Out:
# ('P26',
#  [{'mainsnak': {'snaktype': 'value',
#     'property': 'P26',
#     'hash': '0fbf7f3ccd911618498ffc930f15716461390ec8',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 76,
#       'id': 'Q76'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P580': [{'snaktype': 'value',
#       'property': 'P580',
#       'hash': '36e31a1f1fc64c0f17750153a36cba27351a1065',
#       'datavalue': {'value': {'time': '+1992-10-03T00:00:00Z',
#         'timezone': 0,
#         'before': 0,
#         'after': 0,
#         'precision': 11,
#         'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#        'type': 'time'},
#       'datatype': 'time'}],
#     'P2842': [{'snaktype': 'value',
#       'property': 'P2842',
#       'hash': '7794f0ca5420ffdea20c6359a608482dc6e0f27d',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 10703919,
#         'id': 'Q10703919'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P580', 'P2842'],
#    'id': 'q13133$620F1633-EF24-4930-9026-CBD2168CFE42',
#    'rank': 'normal',
#    'references': [{'hash': '11dfa5bd4bfb803743f3f75ece888f3a06fb084b',
#      'snaks': {'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'e0a1c59f52a603b737eefadeff987a7a2430105b',
#         'datavalue': {'value': 'http://senatorobama.wordpress.com/barack-obamas-family/barack-obamas-marriage-license/',
#          'type': 'string'},
#         'datatype': 'url'}],
#       'P1476': [{'snaktype': 'value',
#         'property': 'P1476',
#         'hash': '770508557f91e42952cc96036d40c03dc97bc849',
#         'datavalue': {'value': {'text': "Barack Obama's Marriage License : President Barack Obama - Fact And Fiction",
#           'language': 'en'},
#          'type': 'monolingualtext'},
#         'datatype': 'monolingualtext'}]},
#      'snaks-order': ['P854', 'P1476']},
#     {'hash': 'a584ef290a26da9e6df827cd9610a2f3efcdfe0c',
#      'snaks': {'P1476': [{'snaktype': 'value',
#         'property': 'P1476',
#         'hash': '1c0098eb9fe29de8bdd5de8f0ac759cc10cbd391',
#         'datavalue': {'value': {'text': 'Obama marks 22nd anniversary (and tells marriage jokes)',
#           'language': 'en'},
#          'type': 'monolingualtext'},
#         'datatype': 'monolingualtext'}],
#       'P123': [{'snaktype': 'value',
#         'property': 'P123',
#         'hash': '42f9d23c0d7d538558fbb93f0d212808758e4867',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 39681,
#           'id': 'Q39681'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P577': [{'snaktype': 'value',
#         'property': 'P577',
#         'hash': 'd81a2692a3b49a43ca1b13a8b0bfe9adb2afb7f3',
#         'datavalue': {'value': {'time': '+2014-10-03T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}],
#       'P407': [{'snaktype': 'value',
#         'property': 'P407',
#         'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 1860,
#           'id': 'Q1860'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'c539b7be2c7415348b0b0e8d8935542681147143',
#         'datavalue': {'value': 'http://www.usatoday.com/story/theoval/2014/10/03/obama-michelle-obama-indiana-anniversary-millennium-steel-service/16661341/',
#          'type': 'string'},
#         'datatype': 'url'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '4be80c9494e2518135e5ba5f4152ea8c0db17bf3',
#         'datavalue': {'value': {'time': '+2014-12-10T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P1476', 'P123', 'P577', 'P407', 'P854', 'P813']},
#     {'hash': '3e82fc81a5826faa2eeacd0df2841aee5a07bb77',
#      'snaks': {'P1476': [{'snaktype': 'value',
#         'property': 'P1476',
#         'hash': 'f5fd4fa77e02aba1c077fdf82fe50f07b3524dde',
#         'datavalue': {'value': {'text': 'Barack and Michelle Obama’s romance made into movie',
#           'language': 'en'},
#          'type': 'monolingualtext'},
#         'datatype': 'monolingualtext'}],
#       'P123': [{'snaktype': 'value',
#         'property': 'P123',
#         'hash': '70622d6ac5b81178178f22a875f07c4e01a3025b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 926175,
#           'id': 'Q926175'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P577': [{'snaktype': 'value',
#         'property': 'P577',
#         'hash': '86b488d9ec07840e4d97a10644ca68e7bae1de53',
#         'datavalue': {'value': {'time': '+2014-12-07T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'},
#        {'snaktype': 'value',
#         'property': 'P577',
#         'hash': '410512ee38cae4231a38649cd6647618274f497e',
#         'datavalue': {'value': {'time': '+2014-12-10T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}],
#       'P407': [{'snaktype': 'value',
#         'property': 'P407',
#         'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 1860,
#           'id': 'Q1860'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P854': [{'snaktype': 'value',
#         'property': 'P854',
#         'hash': 'd0647fd1a89cb3838b1a94bd6e063b56f6e30c20',
#         'datavalue': {'value': 'http://www.thehindu.com/entertainment/barack-and-michelle-obamas-romance-made-into-movie/article6669782.ece',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P1476', 'P123', 'P577', 'P407', 'P854']}]}])

# %%
json.dumps(data['entities'][top_id])
# Out:
# '{"pageid": 14753, "ns": 0, "title": "Q13133", "lastrevid": 1978456816, "modified": "2023-09-20T19:56:52Z", "type": "item", "id": "Q13133", "labels": {"en": {"language": "en", "value": "Michelle Obama"}}, "descriptions": {"en": {"language": "en", "value": "lawyer and former First Lady of the United States"}}, "aliases": {"en": [{"language": "en", "value": "Michelle LaVaughn Obama"}, {"language": "en", "value": "Michelle Robinson"}, {"language": "en", "value": "Michelle LaVaughn Robinson Obama"}, {"language": "en", "value": "First Lady Michelle Obama"}]}, "claims": {"P1280": [{"mainsnak": {"snaktype": "value", "property": "P1280", "hash": "74fe65a11973be93a7744eb5fad7b726a7257bd8", "datavalue": {"value": "162022243", "type": "string"}, "datatype": "external-id"}, "type": "statement", "id": "Q13133$9bf1d5ab-43a4-2cfe-277f-c8d6dcedeafb", "rank": "normal"}], "P735": [{"mainsnak": {"snaktype": "value", "property": "P735", "hash": "10a41aae97ab35773aac349801425770e7feee6e", "datavalue": {"value": {"entity-type": "item", "numeric-id": 15621047, "id": "Q15621047"}, "type": "wikibase-entityid"}, "datatype": "wikibase-item"}, "type": "statement", "qualifiers": {"P1545": [{"snaktype": "value", "property": "P1545", "hash": "2a1ced1dca90648ea7e306acbadd74fc81a10722", "datavalue": {"value": "1", "type": "string"}, "datatype": "string"}]}, "qualifiers-order": ["P1545"], "id": "Q13133$511cba66-4014-435c-0a36-eb3e5756332d", "rank": "preferred"}, {"mainsnak": {"snaktype": "value", "property": "P735", "hash": "46f9a0bfdf5de051898c03b58e70fd273750bb8f", "datavalue": {"value": {"entity-type": "item", "numeric-id": 63100525, "id": "Q63100525"}, "type": "wikibase-entityid"}, "datatype": "wikibase-item"}, "type": "statement", "qualifiers": {"P1545": [{"snaktype": "value", "property": "P1545", "hash": "7241753c62a310cf84895620ea82250dcea65835", "datavalue": {"value": "2", "type": "string"}, "datatype": "string"}]}, "qualifiers-order": ["P1545"], "id": "Q13133$9bf5a76b-4a76-38bf-704e-60bd19ac54e7", "rank": "normal"}], "P109": [{"mainsnak": {"snaktype": "value", "property": "P109", "hash": "9debb9fdf0fc34d323bb3dc5bfa982f468ee7017", "datavalue": {"value": "Michelle Obama signature.svg", "type": "string"}, "datatype": "commonsMedia"}, "type": "statement", "id": "Q13133$dd40dc6a-427d-cd0f-e6cb-f9170310de84", "rank": "normal"}], "P22": [{"mainsnak": {"snaktype": "value", "property": "P22", "hash": "7fa1088b5be4296edb81368d1a069c12e51b28c1", "datavalue": {"value": {"entity-type": "item", "numeric-id": 15982139, "id": "Q15982139"}, "type": "wikibase-entityid"}, "datatype": "wikibase-item"}, "type": "statement", "id": "Q13133$327e5195-44a8-53a8-5f70-50c3c97fa8a3", "rank": "normal", "references": [{"hash": "9782272defb39919e36467d09b622043bc05ac22", "snaks": {"P1476": [{"snaktype": "value", "property": "P1476", "hash": "9f42ba2679d99cb94977af5f230f641e2d3307a7", "datavalue": {"value": {"text": "\'I want to rip Bill Clinton\'s eyes out. Kidding! See, that\'s what gets me into trouble\'", "language": "en"}, "type": "monolingualtext"}, "datatype": "monolingualtext"}], "P123": [{"snaktype": "value", "property": "P123", "hash": "7cc99d0eec7b745edccf680f3347956e14188d2a", "datavalue": {"value": {"entity-type": "item", "numeric-id": 11148, "id": "Q11148"}, "type": "wikibase-entityid"}, "datatype": "wikibase-item"}], "P577": [{"snaktype": "value", "property": "P577", "hash": "f120ada78e249304185e8249f545c7b23e2d0852", "datavalue": {"value": {"time": "+2008-05-04T00:00:00Z", "timezone": 0, "before": 0, "after": 0, "precision": 11, "calendarmodel": "http://www.wikidata.org/entity/Q1985727"}, "type": "time"}, "datatype": "time"}], "P407": [{"snaktype": "value", "property": "P407", "hash": "daf1c4fcb58181b02dff9cc89deb084004ddae4b", "datavalue": {"value": {"entity-type": "item", "numeric-id": 1860, "id": "Q1860"}, "type": "wikibase-entityid"}, "datatype": "wikibase-item"}], "P854": [{"snaktype": "value", "property": "P854", "hash": "fa2109726c398f17ea83ef7c4a301e643b1076a ...

# %%
rs = requests.get(f"https://www.wikidata.org/w/api.php?action=wbgetclaims&format=json&formatversion=2&property=P1280&entity={top_id}")
rs.content
# Out:
# b'{"claims":{"P1280":[{"mainsnak":{"snaktype":"value","property":"P1280","hash":"74fe65a11973be93a7744eb5fad7b726a7257bd8","datavalue":{"value":"162022243","type":"string"},"datatype":"external-id"},"type":"statement","id":"Q13133$9bf1d5ab-43a4-2cfe-277f-c8d6dcedeafb","rank":"normal"}]}}'

# %%
json.loads(rs.content)
# Out:
# {'claims': {'P1280': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P1280',
#      'hash': '74fe65a11973be93a7744eb5fad7b726a7257bd8',
#      'datavalue': {'value': '162022243', 'type': 'string'},
#      'datatype': 'external-id'},
#     'type': 'statement',
#     'id': 'Q13133$9bf1d5ab-43a4-2cfe-277f-c8d6dcedeafb',
#     'rank': 'normal'}]}}

# %%
sorted(data['entities'][top_id]['claims'].keys())
# Out:
# ['P1005',
#  'P1006',
#  'P10097',
#  'P1015',
#  'P102',
#  'P10227',
#  'P10297',
#  'P103',
#  'P10302',
#  'P10328',
#  'P1038',
#  'P106',
#  'P10660',
#  'P10780',
#  'P108',
#  'P10832',
#  'P10882',
#  'P109',
#  'P11194',
#  'P11249',
#  'P11496',
#  'P11646',
#  'P11683',
#  'P11686',
#  'P1185',
#  'P1207',
#  'P1258',
#  'P1263',
#  'P1266',
#  'P1273',
#  'P1280',
#  'P1284',
#  'P1343',
#  'P1368',
#  'P1375',
#  'P140',
#  'P1412',
#  'P1417',
#  'P1430',
#  'P1477',
#  'P1559',
#  'P166',
#  'P1695',
#  'P1712',
#  'P172',
#  'P1728',
#  'P1741',
#  'P18',
#  'P1819',
#  'P1889',
#  'P1890',
#  'P19',
#  'P1953',
#  'P1971',
#  'P2002',
#  'P2003',
#  'P2013',
#  'P2019',
#  'P2048',
#  'P21',
#  'P213',
#  'P214',
#  'P2163',
#  'P2190',
#  'P22',
#  'P2267',
#  'P227',
#  'P2390',
#  'P2435',
#  'P244',
#  'P2471',
#  'P25',
#  'P26',
#  'P2600',
#  'P2604',
#  'P2605',
#  'P2607',
#  'P2611',
#  'P2638',
#  'P268',
#  'P269',
#  'P27',
#  'P271',
#  'P2949',
#  'P2963',
#  'P3056',
#  'P3065',
#  'P31',
#  'P3106',
#  'P3144',
#  'P3221',
#  'P3222',
#  'P3305',
#  'P3368',
#  'P3373',
#  'P3388',
#  'P3417',
#  'P3430',
#  'P345',
#  'P3479',
#  'P349',
#  'P3509',
#  'P3553',
#  'P373',
#  'P3812',
#  'P3836',
#  'P3845',
#  'P3846',
#  'P39',
#  'P396',
#  'P40',
#  'P4159',
#  'P4332',
#  'P434',
#  'P4438',
#  'P4515',
#  'P4619',
#  'P463',
#  'P4666',
#  'P4682',
#  'P4779',
#  'P4782',
#  'P4862',
#  'P4985',
#  'P5033',
#  'P5034',
#  'P5284',
#  'P5298',
#  'P53',
#  'P5340',
#  'P5421',
#  'P551',
#  'P5534',
#  'P5587',
#  'P5617',
#  'P569',
#  'P5905',
#  'P6119',
#  'P6200',
#  'P6262',
#  'P6327',
#  'P6394',
#  'P646',
#  'P648',
#  'P6517',
#  'P6683',
#  'P6722',
#  'P6723',
#  'P6760',
#  'P6868',
#  'P6886',
#  'P69',
#  'P691',
#  'P7031',
#  'P7214',
#  'P7215',
#  'P7293',
#  'P7303',
#  'P734',
#  'P735',
#  'P7369',
#  'P7400',
#  'P7578',
#  'P7699',
#  'P7859',
#  'P793',
#  'P8094',
#  'P8125',
#  'P8179',
#  'P8189',
#  'P8309',
#  'P8313',
#  'P8462',
#  'P856',
#  'P8687',
#  'P8848',
#  'P8849',
#  'P8850',
#  'P8851',
#  'P910',
#  'P9171',
#  'P935',
#  'P9404',
#  'P9493',
#  'P950',
#  'P9743',
#  'P990',
#  'P9984',
#  'P9995']

# %%
from spacy import displacy
from promptedgraphs.config import Config
from promptedgraphs.entity_recognition import extract_entities

labels = {
    "person:name": "Name of the person.",
    "person:date_of_birth": "Date of birth of the person.",
    "person:email": "Email address of the person. Must be unique.",
    "person:phone_number": "Phone number of the person.",
    "person:address": "Physical address of the person.",
    "person:profile_picture": "URL or path to the profile picture of the person.",
    "relationship:relationship_type": "Type of relationship (e.g., friend, family, colleague, spouse).",
    "person_relationship:start_date": "Start date of the relationship.",
    "person_relationship:end_date": "End date of the relationship, if applicable."
}

question = "Where was the husband of Michelle Obama born?"

# Label Sentiment
ents = []
async for msg in extract_entities(
    text=question,
    labels=labels,
    config=Config(),  # Reads `OPENAI_API_KEY` from .env file or environment
):
    ents.append(msg)

# Show Results using spacy.displacy
displacy.render(
    {
        "text": question,
        "ents": [e.to_dict() for e in ents],
    },
    style="ent",
    jupyter=True,
    manual=True,
)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Where was the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     husband
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">person_relationship:relationship_type</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michelle Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">person:name</span>
# </mark>
#  born?</div></span>

# %%
ents
# Out:
# [EntityReference(start=14, end=21, label='person_relationship:relationship_type', text='husband', reason='relationship type'),
#  EntityReference(start=25, end=39, label='person:name', text='Michelle Obama', reason='person name')]
